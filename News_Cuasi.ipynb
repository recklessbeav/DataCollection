# %%
import requests
from bs4 import BeautifulSoup
import pprint
import pandas as pd
import numpy as np

# %%
url = 'https://newsapi.org/v2/everything?'

# %%
api_key = "c24ef57ace524bda83b91240acbad6da"

# %%
import json

parameters = {
    
        'apiKey': api_key,
        'domain': "nytimes",
        'from': '2021-03-11',
        'to': '2021-03-12',
        'q': "all"
  
    
}

response = requests.get(url, params = parameters)
response_json = response.json()


with open('news_data.json', 'w') as outfile:
    json.dump(response_json, outfile)  
response_json
# Out:
# {'status': 'ok',
#  'totalResults': 48963,
#  'articles': [{'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'David Murphy',
#    'title': 'How to Back Up All of Your Google Data',
#    'description': 'It’s more than likely you’ll live happily with your Google account until such time as Jeeves comes back from the dead to reassert dominance in the search market (forever, in other words). However, I’ve encountered\xa0a few weird instances lately of Google deleti…',
#    'url': 'https://lifehacker.com/how-to-back-up-all-of-your-google-data-1846450076',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/f4mbhql4ythhftynl7mx.jpg',
#    'publishedAt': '2021-03-11T20:00:00Z',
#    'content': 'Its more than likely youll live happily with your Google account until such time as Jeeves comes back from the dead to reassert dominance in the search market (forever, in other words). However, Ive … [+6259 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Thorin Klosowski and Beth Skwarecki',
#    'title': "What's the Difference Between All These Running Shoes?",
#    'description': 'When you walk into a shoe store, you’ll see hundreds of pairs to choose from. From barefoot running shoes to a $200 pair of Nike’s. The fact of the matter is, the “perfect” running shoe doesn’t exist. Everyone needs a different type of shoe, and when it boils…',
#    'url': 'https://lifehacker.com/whats-the-difference-between-all-these-running-shoes-476458686',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/18l4j8r31fnx0jpg.jpg',
#    'publishedAt': '2021-03-12T20:30:00Z',
#    'content': 'When you walk into a shoe store, youll see hundreds of pairs to choose from. From barefoot running shoes to a $200 pair of Nikes. The fact of the matter is, the perfect running shoe doesnt exist. Eve… [+6438 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Katherine Rosman and Reggie Ugwu',
#    'title': 'What Really Happened at ‘Reply All’?',
#    'description': 'A podcast was applauded for its reporting on embedded racism in the workplace. It didn’t make it to the third episode.',
#    'url': 'https://www.nytimes.com/2021/03/10/style/reply-all-test-kitchen.html',
#    'urlToImage': 'https://static01.nyt.com/images/2021/02/26/fashion/00REPLYALL/00REPLYALL-facebookJumbo.jpg',
#    'publishedAt': '2021-03-11T01:24:27Z',
#    'content': 'Mr. Eddings, who was a host of The Nod, a Gimlet podcast about Black culture, wrote in his thread that his intention was not to get people to stop listening to the show. But online, many railed again… [+1468 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Joseph Green',
#    'title': 'Save £450 on the phone to end all cameras',
#    'description': 'SAVE £450: The Samsung Galaxy S20 Ultra 5G is on sale for £749 on Amazon, saving you 38% on list price.\n\nThe Samsung Galaxy S20 Ultra 5G is a really impressive smartphone, but what sets it apart from the competition is its cameras. It packs a 48MP telephoto c…',
#    'url': 'https://mashable.com/uk/shopping/march-12-best-samsung-galaxy-s20-ultra-5g-deal/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F03%252F12%252F36%252F24ad2838267148d094709b09f6cee4f4.cbf0c.png%252F1200x630.png?signature=oNdBtpCK3QXvHbmAq84PQMsRJl0=',
#    'publishedAt': '2021-03-12T05:10:00Z',
#    'content': 'SAVE £450: The Samsung Galaxy S20 Ultra 5G is on sale for £749 on Amazon, saving you 38% on list price.\r\nThe Samsung Galaxy S20 Ultra 5G is a really impressive smartphone, but what sets it apart from… [+917 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Abigail Bassett',
#    'title': 'The 2021 Volkswagen ID. 4 ticks all the boxes, except one',
#    'description': 'Volkswagen, once a dabbler in electric vehicles, is now betting its future on the technology. And the new Volkswagen ID.4 — a five-passenger, fully-electric crossover with a starting price of $33,995 (before federal or state incentives) — is its first global …',
#    'url': 'http://techcrunch.com/2021/03/11/the-2021-volkswagen-id-4-ticks-all-the-boxes-except-one/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/03/vw-Large-12562-2021ID.4ProSwithGradientPackage.jpg?w=764',
#    'publishedAt': '2021-03-11T19:21:10Z',
#    'content': 'Volkswagen, once a dabbler in electric vehicles, is now betting its future on the technology. And the new Volkswagen ID.4 a five-passenger, fully-electric crossover with a starting price of $33,995 (… [+14520 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Sopan Deb',
#    'title': 'Your N.B.A. Coronavirus Questions, Answered',
#    'description': 'Can fans attend all games? Will players be vaccinated? Was All-Star weekend safe? Read on to find out.',
#    'url': 'https://www.nytimes.com/2021/03/11/sports/basketball/nba-covid-vaccine-players.html',
#    'urlToImage': 'https://static01.nyt.com/images/2021/03/11/sports/11nba-virus/11nba-virus-facebookJumbo.jpg',
#    'publishedAt': '2021-03-11T22:49:26Z',
#    'content': 'Why havent I seen Wayne Knight in the ads for Space Jam 2?\r\nIm sorry, Mr. Knight. I cant answer that.\r\nRecently, Gov. Greg Abbott, Republican of Texas, ended the states mask mandate and said that all… [+1110 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'David Nield',
#    'title': 'How to Back Up All Your Photos Without a Cloud Subscription',
#    'description': 'The photos and videos you’ve captured are probably the most important files on your phone, which is why Apple, Google and other storage service providers want to give you ways to get these pictures and movies up into the cloud as quickly as possible. As conve…',
#    'url': 'https://gizmodo.com/how-to-back-up-all-your-photos-without-a-cloud-subscrip-1846434752',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/auvsqycsa5rv3pgtfil9.jpg',
#    'publishedAt': '2021-03-11T13:30:00Z',
#    'content': 'The photos and videos youve captured are probably the most important files on your phone, which is why Apple, Google and other storage service providers want to give you ways to get these pictures an… [+6518 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Sam Blum',
#    'title': 'How Do You Tell Your Boyfriend to Stop Eating Your Takeout?',
#    'description': 'Not all advice need be professional. Sometimes your problems merit a bit of unvarnished honesty from a dude equipped with nothing more than a computer and a conscience. Luckily for you, I’m that guy. Welcome back to Tough Love.Read more...',
#    'url': 'https://lifehacker.com/how-do-you-tell-your-boyfriend-to-stop-eating-your-take-1846455275',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/xxvyuj5iuguiuaqrth5i.jpg',
#    'publishedAt': '2021-03-11T19:00:00Z',
#    'content': 'Not all advice need be professional. Sometimes your problems merit a bit of unvarnished honesty from a dude equipped with nothing more than a computer and a conscience. Luckily for you, Im that guy. … [+6773 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Joseph Green',
#    'title': 'Unblock all your favourite streaming sites with this high-speed VPN',
#    'description': 'SAVE 75%: A two-year subscription to Ivacy VPN\r\n is on sale for £1.76 per month as of March 11, saving you 75% on list price.\n\nExpressVPN is probably the best service for unlocking streaming sites from around the world, but Ivacy VPN is not far behind, and it…',
#    'url': 'https://mashable.com/uk/shopping/march-11-best-ivacy-vpn-deal/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F03%252F11%252Fc3%252Feb6ce25002bc47d09c074682b7b07ebf.ed217.jpg%252F1200x630.jpg?signature=gpCFhx_7XkgBjYBXxa5tQskQOE0=',
#    'publishedAt': '2021-03-11T05:10:00Z',
#    'content': 'SAVE 75%: A two-year subscription to Ivacy VPN\r\n is on sale for £1.76 per month as of March 11, saving you 75% on list price.\r\nExpressVPN is probably the best service for unlocking streaming sites fr… [+1015 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Covid pandemic: Biden to order all US adults be eligible for vaccine',
#    'description': 'The president is set to announce the move during a speech on Thursday evening.',
#    'url': 'https://www.bbc.co.uk/news/world-us-canada-56368328',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/14021/production/_117535918_gettyimages-1231650547.jpg',
#    'publishedAt': '2021-03-12T00:17:14Z',
#    'content': 'image copyrightGetty Images\r\nimage captionMr Biden is set to announce the move during a speech on Thursday evening\r\nPresident Joe Biden is set to order US states to make all adults eligible for Covid… [+1110 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jay Peters',
#    'title': 'Let this robot Twitter composer serenade you with randomly generated music',
#    'description': 'A Twitter bot, @MelodyBot3456, posts randomly generated music every hour, and I’ve been listening to its songs all week. The songs are often bizarre and regularly veer in unexpected and hilarious directions.',
#    'url': 'https://www.theverge.com/tldr/2021/3/12/22327417/robot-twitter-composer-randomly-generated-music-melodybot',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/FmoEpz5WKVg8fC4IG_TZ0MNvBpc=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/13292797/acastro_181016_1777_music_0001.jpg',
#    'publishedAt': '2021-03-12T17:32:01Z',
#    'content': 'Illustration by Alex Castro / The Verge\r\n\n \n\n I have been listening to robot-made music all week. No, not Daft Punk, but randomly generated music posted every hour by a Twitter bot, @MelodyBot3456. A… [+2197 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Italy's Benetton group suspends all new orders from Myanmar - Reuters",
#    'description': "Italy's Benetton group suspends all new orders from Myanmar\xa0\xa0Reuters",
#    'url': 'https://www.reuters.com/article/us-benetton-myanmar-idUSKBN2B41ZH',
#    'urlToImage': None,
#    'publishedAt': '2021-03-12T15:50:20Z',
#    'content': 'Retail\r\nReuters Staff\r\nROME (Reuters) - Italys Benetton group on Friday said it had suspended all new orders from Myanmar with immediate effect due to rising violence after the ousting of Aung San Su… [+581 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Qatar offers COVID-19 vaccinations to all in MotoGP - Reuters',
#    'description': 'Qatar has offered COVID-19 vaccinations to all members of the MotoGP paddock attending pre-season testing and opening races there, the sport announced on Thursday.',
#    'url': 'https://www.reuters.com/article/health-coronavirus-motogp-qatar-int-idUSKBN2B32WN',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-03-11T20:24:00Z',
#    'content': 'By Reuters Staff\r\n(Reuters) - Qatar has offered COVID-19 vaccinations to all members of the MotoGP paddock attending pre-season testing and opening races there, the sport announced on Thursday.\r\nMoto… [+1101 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Praveen Menon',
#    'title': "All coronavirus restrictions lifted from New Zealand's largest city - Reuters",
#    'description': "All remaining restrictions in New Zealand's largest city Auckland have been lifted after no locally transmitted cases of coronavirus were reported for two weeks, Prime Minister Jacinda Ardern said on Friday.",
#    'url': 'https://www.reuters.com/article/us-health-coronavirus-newzealand-idUSKBN2B3384',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-03-11T23:59:00Z',
#    'content': 'WELLINGTON (Reuters) - All remaining restrictions in New Zealands largest city Auckland have been lifted after no locally transmitted cases of coronavirus were reported for two weeks, Prime Minister … [+1006 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Meghan Moravcik Walbert on Offspring, shared by Meghan Moravcik Walbert to Lifehacker',
#    'title': "Remember, Your Teenager Is Not Your 'Project'",
#    'description': 'All parents (or at least all decent parents) want the best for their kids. They want them to succeed in school so they can go on to be successful in life. They want to raise children who will become adults who are honest and full of integrity and have a solid…',
#    'url': 'https://offspring.lifehacker.com/remember-your-teenager-is-not-your-project-1846449976',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/ai5ak1fx0y3qdak1ogqu.jpg',
#    'publishedAt': '2021-03-11T14:30:00Z',
#    'content': 'All parents (or at least all decent parents) want the best for their kids. They want them to succeed in school so they can go on to be successful in life. They want to raise children who will become … [+3321 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Analysis by Stephen Collinson and Maeve Reston, CNN',
#    'title': "Analysis: 'I need you': Biden asks Americans to do their part to help end Covid crisis",
#    'description': 'President Joe Biden offered Americans the tantalizing hope of a return to an all but forgotten pre-pandemic normalcy within months Thursday, promising all American adults could get the vaccine by May and setting a goal of family and friend gatherings by July …',
#    'url': 'https://www.cnn.com/2021/03/12/politics/joe-biden-primetime-speech-covid-vaccine-may/index.html',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210311201521-03-biden-address-0311-super-tease.jpg',
#    'publishedAt': '2021-03-12T05:20:54Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'Jeramy Johnson',
#    'title': "Amazon's Build It is a crowdfunding platform that's all upside",
#    'description': "If Amazon builds it, will they come?\n\n\n\nA few weeks ago, Amazon made what I think was a major product announcement that might have flown under your radar. No, it wasn't that the Echo Show 10 (3rd Gen) or Echo Frames (2nd Gen) finally became available for gene…",
#    'url': 'https://www.androidcentral.com/amazons-new-kickstarter-and-indiegogo-competitor-aims-ease-customers-crowdfunding-anxieties',
#    'urlToImage': 'https://www.androidcentral.com/sites/androidcentral.com/files/styles/large/public/article_images/2021/03/amazon-built-it-devices-lifestyle.jpg',
#    'publishedAt': '2021-03-11T12:00:02Z',
#    'content': "Source: Amazon\r\nA few weeks ago, Amazon made what I think was a major product announcement that might have flown under your radar. No, it wasn't that the Echo Show 10 (3rd Gen) or Echo Frames (2nd Ge… [+6627 chars]"},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Margaret Lyons',
#    'title': 'How Much Watching Time Do You Have This Weekend?',
#    'description': 'There’s always plenty to watch; this weekend our critic recommends a gorgeous new animated show, a terrific stand-up special, and all of “My So-Called Life.”',
#    'url': 'https://www.nytimes.com/2021/03/11/arts/television/so-called-life-streaming-hulu.html',
#    'urlToImage': 'https://static01.nyt.com/images/2021/03/12/arts/11Watching-Ghosts/11Watching-Ghosts-facebookJumbo.jpg',
#    'publishedAt': '2021-03-11T22:34:48Z',
#    'content': 'City of GhostsWhen to watch: Now, on Netflix.\r\nThis new six-part childrens show uses low-key, naturalistic voice acting and animated televisions most gorgeous use of light and texture to tell snapsho… [+350 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Jonathan Shieber',
#    'title': 'Snyk raises $300 million at a $4.7 billion valuation as employees cash in and the security company beefs up',
#    'description': 'Snyk, a developer of application security technology, is now worth $4.7 billion after a new fundraising and secondary sale that totaled $300 million. In all, investors have poured $470 million into the company after this new investment, which was led by Accel…',
#    'url': 'http://techcrunch.com/2021/03/10/snyk-raises-300-million-at-a-4-7-billion-valuation-as-employees-cash-in-and-the-security-company-beefs-up/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/11/space-money.jpg?w=711',
#    'publishedAt': '2021-03-11T00:59:41Z',
#    'content': 'Snyk, a developer of application security technology, is now worth $4.7 billion after a new fundraising and secondary sale that totaled $300 million.\r\nIn all, investors have poured $470 million into … [+3035 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Alexandra Ames',
#    'title': 'Here are the new features and upgraded virtual Startup Alley experience at TC Disrupt 2021',
#    'description': 'Spring may be just around the corner (in the U.S., anyway), but it’s never too early to start planning for TechCrunch Disrupt 2021, which takes place on September 21-23. This all-virtual conference allows makers, innovators, entrepreneurs and investors from a…',
#    'url': 'http://techcrunch.com/2021/03/12/introducing-the-updated-virtual-startup-alley-experience-at-tc-disrupt-2021/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/03/TC_Disrupt_21_WebOverviewCard_2000x1155.png?w=693',
#    'publishedAt': '2021-03-12T17:47:03Z',
#    'content': 'Spring may be just around the corner (in the U.S., anyway), but its never too early to start planning for TechCrunch Disrupt 2021, which takes place on September 21-23. This all-virtual conference al… [+2627 chars]'}]}
