# %%
import requests
from bs4 import BeautifulSoup
import pprint
import pandas as pd
import numpy as np

# %%
url = 'https://newsapi.org/v2/everything?'

# %%
api_key = "c24ef57ace524bda83b91240acbad6da"

# %%
parameters = {
    'apiKey': api_key,
    'domain': "nytimes",
    'from': '2021-03-11',
    'to': '2021-03-12',
    'q': "covid"
}

response = requests.get(url, params = parameters)
response_json = response.json()

response_json
# Out:
# {'status': 'ok',
#  'totalResults': 36280,
#  'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Andrew Tarantola',
#    'title': 'Everything you need to know about at-home COVID testing',
#    'description': 'COVID vaccination efforts continue to gain momentum both in the US and around the world but that doesn’t mean we’re out of the pandemic woods just yet. Regular testing remains an important factor in helping slow the spread of the disease but has typically req…',
#    'url': 'https://www.engadget.com/find-out-if-you-have-covid-from-the-comfort-of-your-own-home-173043438.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/2pOVijKGLtLN1xeZgyDmJg--~B/aD0zNjc4O3c9NTUwMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2021-03/a0a48be0-8351-11eb-bf2f-c2f9a315da5a.cf.jpg',
#    'publishedAt': '2021-03-12T17:30:43Z',
#    'content': 'COVID vaccination efforts continue to gain momentum both in the US and around the world but that doesnt mean were out of the pandemic woods just yet. Regular testing remains an important factor in he… [+7436 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Matt Simon',
#    'title': 'The Perplexing Psychology of Returning to ‘Normal’',
#    'description': 'For a year now, we’ve been living in constant fear of Covid-19. But when you get that vaccine in your arm, it’s not like your stress will magically melt away.',
#    'url': 'https://www.wired.com/story/the-perplexing-psychology-of-returning-to-normal/',
#    'urlToImage': 'https://media.wired.com/photos/604a93f13033a63758ebda2d/191:100/w_1280,c_limit/Science_psychology_1282214892.jpg',
#    'publishedAt': '2021-03-12T12:00:00Z',
#    'content': 'Last night, on the anniversary of what was more or less the start of the worst year of our collective lives, President Joe Biden shocked the nation with a vibe most of us had long forgotten: optimism… [+3464 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Sam Blum',
#    'title': 'How to Date During the Pandemic Without Going on Another Damn Walk',
#    'description': 'The pandemic has taken dating from a difficult and necessary evil to a basically impossible and dangerous temptation. But with COVID-19 cases waning internationally and vaccination rates increasing daily in the U.S., you’ll likely be able to stumble through a…',
#    'url': 'https://lifehacker.com/how-to-date-during-the-pandemic-without-going-on-anothe-1846466443',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/ndyhxqkomiishogdsdak.jpg',
#    'publishedAt': '2021-03-12T21:30:00Z',
#    'content': 'The pandemic has taken dating from a difficult and necessary evil to a basically impossible and dangerous temptation. But with COVID-19 cases waning internationally and vaccination rates increasing d… [+4059 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Mike Winters on Two Cents, shared by Mike Winters to Lifehacker',
#    'title': 'How to Qualify for 100% Subsidized COBRA Premiums',
#    'description': 'As part of an expanded COBRA program, President Biden’s COVID relief bill includes a temporary healthcare subsidy that will cover 100% of your premiums if you’ve been laid off or have reduced hours of employment during the pandemic. Coverage is from April 1 t…',
#    'url': 'https://twocents.lifehacker.com/how-to-qualify-for-100-subsidized-cobra-premiums-1846466275',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/m7h4b2siynqzx7arbuvm.jpg',
#    'publishedAt': '2021-03-12T19:30:00Z',
#    'content': 'As part of an expanded COBRA program, President Bidens COVID relief bill includes a temporary healthcare subsidy that will cover 100% of your premiums if youve been laid off or have reduced hours of … [+2597 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': None,
#    'title': 'Covid: The man with "super antibodies"',
#    'description': 'John Hollis has antibodies that can kill the virus and variants but the discovery was nearly missed.',
#    'url': 'https://www.bbc.co.uk/news/av/world-us-canada-56324050',
#    'urlToImage': 'https://ichef.bbci.co.uk/images/ic/400xn/p099b25p.jpg',
#    'publishedAt': '2021-03-11T00:01:41Z',
#    'content': 'John Hollis didnt realise hed been infected with Covid-19. But he later discovered hes one of the rare people who has super antibodies. \r\nThe antibodies are so good at killing the virus, hes practica… [+216 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Alice Proujansky',
#    'title': 'Why Black Women Are Rejecting Hospitals in Search of Better Births',
#    'description': 'Some mothers are seeking alternatives, worried about Covid-19 and racial inequities in health care.',
#    'url': 'https://www.nytimes.com/2021/03/11/nyregion/birth-centers-new-jersey.html',
#    'urlToImage': 'https://static01.nyt.com/images/2021/01/26/nyregion/00NJBIRTHCENTER-promoSTILL/00NJBIRTHCENTER-promoSTILL-facebookJumbo-v3.jpg',
#    'publishedAt': '2021-03-11T10:00:26Z',
#    'content': 'Birth centers are sort of halfway points between hospital births and home births. They serve women with low-risk pregnancies and use midwives, who have medical training, and doulas, a nonmedical posi… [+922 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Lacey Smith',
#    'title': 'Social Good Summit: Coronavirus and the digital divide',
#    'description': 'Moderator Dr. Chris Emdin leads the panel with Dana Floberg,\xa0Lakisha Young, Becky Pringle, Dr. Maria Coady on Covid, remote learning, and the digital divide in schools. Read more...More about Mashable Video, School, Social Good Summit, Covid 19, and Digital D…',
#    'url': 'https://mashable.com/video/social-good-summit-digital-divide-schools/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F03%252F11%252F1c%252F0970b8efa72c46e48382d101cbcfe2a9.7506f.png%252F1200x630.png?signature=3reN-xJTW3Q6t6q_ENo41G2hb_c=',
#    'publishedAt': '2021-03-11T20:40:28Z',
#    'content': 'Moderator Dr. Chris Emdin leads the panelwithDana Floberg,\xa0Lakisha Young, Becky Pringle, Dr. Maria Coady on Covid, remote learning, and the digital divide in schools.'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': None,
#    'title': 'Tokyo 2020: China offers Covid vaccine doses for Olympic and Paralympic athletes',
#    'description': "The Chinese Olympic Committee offers Covid vaccine doses for athletes competing at this summer's Tokyo Games and at Beijing 2022.",
#    'url': 'https://www.bbc.co.uk/sport/olympics/56359057',
#    'urlToImage': 'https://ichef.bbci.co.uk/live-experience/cps/624/cpsprodpb/135B2/production/_117528297_tokyo.jpg',
#    'publishedAt': '2021-03-11T12:48:28Z',
#    'content': 'The Tokyo Olympics was due to start on 24 July 2020 but was postponed for a year because of the coronavirus pandemic\r\nThe Chinese Olympic Committee has offered Covid vaccine doses for those competing… [+1088 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'The Little Things: A crime thriller but not as you know it',
#    'description': 'Denzel Washington, Rami Malek and Jared Leto on obsession, Covid-19 and getting into character.',
#    'url': 'https://www.bbc.co.uk/news/entertainment-arts-55718906',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/E64D/production/_116575985_little_things_denzel.jpg',
#    'publishedAt': '2021-03-11T01:22:55Z',
#    'content': 'By Emma SaundersEntertainment reporter\r\nimage copyrightWarner Bros\r\nimage captionWashington plays hardened Deputy Sheriff Joe "Deke" Deacon\r\n"A cornucopia of talent" - that\'s how director John Lee Ha… [+7001 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Covid stimulus: Biden signs $1.9tn relief bill into law',
#    'description': 'The US government has now spent more than $5tn on recovery efforts during the pandemic.',
#    'url': 'https://www.bbc.co.uk/news/world-us-canada-56364944',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/14021/production/_117535918_gettyimages-1231650547.jpg',
#    'publishedAt': '2021-03-11T19:18:06Z',
#    'content': 'image copyrightGetty Images\r\nUS President Joe Biden has signed a $1.9tn (£1.4tn) economic relief bill that aims to help Americans impacted by the Covid-19 pandemic into law.\r\nThe bill includes $1,400… [+5536 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Covid: Texas and Mississippi lifting restrictions too soon?',
#    'description': 'Two US states are lifting compulsory coronavirus restrictions, but are they in a position to do so?',
#    'url': 'https://www.bbc.co.uk/news/world-us-canada-56297329',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/7FF8/production/_117506723_austin_mask_gettyimages-1231493646.jpg',
#    'publishedAt': '2021-03-11T00:44:08Z',
#    'content': 'By Jake HortonBBC Reality Check\r\nimage captionTexas is some way off reaching wider immunity through vaccinations\r\nThe governors of the US states of Texas and Mississippi have lifted all compulsory Co… [+5192 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': None,
#    'title': 'Biden: Covid-19 relief deal puts working people first',
#    'description': 'President Joe Biden touted his $1.9 trillion Covid-19 stimulus deal while speaking from the White House Rose Garden, saying it "changes the paradigm" for workers in the United States.',
#    'url': 'https://www.cnn.com/videos/politics/2021/03/12/joe-biden-middle-class-coronavirus-relief-deal-sot-nr-vpx.cnn',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312150228-03-white-house-covid-relief-event-0312-super-tease.jpg',
#    'publishedAt': '2021-03-12T21:39:34Z',
#    'content': None},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': None,
#    'title': 'Late-night TV marks pandemic anniversary',
#    'description': 'Late-night hosts Stephen Colbert, Seth Meyers, Jimmy Kimmel and Jimmy Fallon commemorate the one year anniversary of the Covid-19 pandemic.',
#    'url': 'https://www.cnn.com/videos/media/2021/03/12/colbert-late-night-pandemic-anniversary-orig.cnn',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312024345-stephen-colbert-lockdown-one-year-super-tease.jpg',
#    'publishedAt': '2021-03-12T09:07:32Z',
#    'content': ''},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Dr. Sanjay Gupta, CNN Chief Medical Correspondent',
#    'title': 'Dr. Gupta: One year of living in the shadow of a pandemic',
#    'description': 'Today, March 11, marks one year since the World Health Organization declared Covid-19, the disease caused by the novel coronavirus, a pandemic.',
#    'url': 'https://www.cnn.com/2021/03/11/health/who-anniversary-pandemic-declared-gupta/index.html',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/201216115648-south-korea-coronavirus-1216-01-super-tease.jpg',
#    'publishedAt': '2021-03-11T12:23:08Z',
#    'content': '(CNN)Today, March 11, marks one year since the World Health Organization declared Covid-19, the disease caused by the novel coronavirus, a pandemic. \r\nIn the first months of 2020, as the unprecedente… [+7818 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': None,
#    'title': "Top ex-Obama strategist grades Biden's speech",
#    'description': "David Axelrod, who advised former President Barack Obama, assesses President Joe Biden's speech addressing the nation about the Covid-19 pandemic.",
#    'url': 'https://www.cnn.com/videos/politics/2021/03/12/david-axelrod-joe-biden-primetime-address-coronavirus-cpt-vpx.cnn',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210311213640-david-axelrod-super-tease.jpg',
#    'publishedAt': '2021-03-12T02:39:59Z',
#    'content': None},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': "UPDATE 1-South Africa's Aspen Pharmacare reports 18% drop in half-year profit - Reuters",
#    'description': '* Tech transfer for J&J COVID-19 vaccine by Q2 (Adds details of COVID-19 vaccine, numbers)',
#    'url': 'https://www.reuters.com/article/aspen-pharmacare-results-idUSL8N2L961U',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-03-11T16:53:00Z',
#    'content': 'By Reuters Staff\r\n* Profit from continuing operations up 11%\r\n* Revenues up 17% led by demand for drugs\r\n* Tech transfer for J&amp;J COVID-19 vaccine by Q2 (Adds details of COVID-19 vaccine, numbers)… [+1937 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Natasha Mascarenhas',
#    'title': '5 takeaways from the Coursera IPO filing',
#    'description': 'Coursera’s S-1 dropped last Friday, giving us a glimpse of the financial impact that COVID-19 had on a large edtech company. We worked through the numbers on the day the filing happened, but here are the core data points: Coursera’s 2020 revenue came to $293.…',
#    'url': 'http://techcrunch.com/2021/03/11/5-takeaways-from-the-coursera-ipo-filing/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/01/money-explosion-gradient-01.jpg?w=711',
#    'publishedAt': '2021-03-11T17:00:54Z',
#    'content': 'Courseras S-1 dropped last Friday, giving us a glimpse of the financial impact that COVID-19 had on a large edtech company.\r\nWe worked through the numbers on the day the filing happened, but here are… [+6157 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Rachel Kraus',
#    'title': 'How much, when, and for whom: What to know about the third stimulus checks.',
#    'description': "It's time for the IRS to start pushing those pencils again, because a new round of COVID-19 stimulus checks will be going out to Americans soon.\nOn Wednesday, Congress passed a $1.9 trillion COVID relief bill called the American Rescue Plan. It includes a man…",
#    'url': 'https://mashable.com/article/third-economic-impact-stimulus-payments-check/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F03%252F11%252F5e%252Fc215deb017874e6d9cdb21031dc2e18c.26102.jpg%252F1200x630.jpg?signature=YmyO8NI4fpKcZV4xcLXV7J_SHj0=',
#    'publishedAt': '2021-03-11T02:26:55Z',
#    'content': "It's time for the IRS to start pushing those pencils again, because a new round of COVID-19 stimulus checks will be going out to Americans soon.\r\nOn Wednesday, Congress passed a $1.9 trillion COVID r… [+2315 chars]"},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Matt Novak',
#    'title': "'Fake News' About Covid-19 in Malaysia Can Now Get You Three Years in Prison",
#    'description': 'The Malaysian government instituted an ordinance against “fake news” on Friday in an effort to crack down on misinformation about the coronavirus pandemic, according to multiple news outlets in the region. Anyone prosecuted for spreading fake news faces a max…',
#    'url': 'https://gizmodo.com/fake-news-about-covid-19-in-malaysia-can-now-get-you-th-1846462669',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/ch58brejjx3nczbmxg2x.jpg',
#    'publishedAt': '2021-03-12T12:30:00Z',
#    'content': 'The Malaysian government instituted an ordinance against fake news on Friday in an effort to crack down on misinformation about the coronavirus pandemic, according to multiple news outlets in the reg… [+1745 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Flora Charner and Marcia Reverdosa, CNN',
#    'title': 'Brazil plunges into crisis as a second wave and deadly new variant overwhelm hospitals',
#    'description': '• 16 states no longer require face coverings\n• Biden announces plans to purchase 100 million more coronavirus vaccine doses\n• Covid case and death rates were higher in GOP-led states in second half of 2020, study finds',
#    'url': 'https://www.cnn.com/2021/03/10/americas/brazil-variant-covid-icu-crisis-intl/index.html',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210310165354-03-brazil-covid-icus-intl-super-tease.jpg',
#    'publishedAt': '2021-03-11T02:06:32Z',
#    'content': '(CNN)A second wave of Covid-19 is ripping through Brazil, pushing hospitals and ICUs toward collapse and claiming record numbers of daily deaths.\r\nWhile a new variant of the coronavirus spreads throu… [+9234 chars]'}]}
